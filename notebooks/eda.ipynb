# %% [markdown]
# # Credit Risk Dataset - Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/application_train.csv')
print('Shape:', df.shape)
df.head()

# %%
df.info()

# %%
df.describe().T

# %%
missing = pd.DataFrame({'Missing Count': df.isnull().sum(),'Missing Percentage': round(df.isnull().mean()*100,2)})
missing.sort_values(by='Missing Percentage', ascending=False).head(20)
